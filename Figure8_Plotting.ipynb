# %%
import anndata, pickle, os, fnmatch, math, random
import scipy.stats as stats
import statistics as st
import scanpy as sc
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib as mlp
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import colors
from matplotlib.colors import ListedColormap
from matplotlib.ticker import MultipleLocator, LogLocator, LogFormatter, LogFormatterSciNotation, MaxNLocator
import matplotlib.patches as mpatches

# %%
'''IMPORTING FUNCTIONS FROM GENERAL FUNCTIONS FILE'''

# %run GeneralFunctions.ipynb
# %run Figure8_Functions.ipynb

# %%
savePath = 'F:/Figures/Figure8/PlasticityComparisons' 
plottingFigure8(plastComparLst, 'PlasticityComparisons', 'PlasticityComparisons_noSexGenes', savePath)
# Out:
# C:\Users\Hlab\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\Hlab\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\Hlab\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\Hlab\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [21], line 2
#       1 savePath = 'F:/Figures/Figure8/PlasticityComparisons'
# ----> 2 plottingFigure8(plastComparLst, 'PlasticityComparisons', 'PlasticityComparisons_noSexGenes', savePath)
#
# File ~\AppData\Local\Temp\ipykernel_21376\172975201.py:12, in plottingFigure8(sampleComparLst, sampleFolder_sexGenes, sampleFolder_noSexGenes, savePath)
#       8 obj_noSexGenes = sc.read(f'F:/SampleData/{sampleFolder_noSexGenes}/{condition}_{sample1_name}_{sample2_name}.h5ad')
#      10 diffSex = comparingSex(sample1_name, sample2_name)
# ---> 12 figure8(obj_sexGenes, obj_noSexGenes, lst, diffSex, savePath)
#
# File ~\AppData\Local\Temp\ipykernel_21376\3469950960.py:64, in figure8(obj_sexGenes, obj_noSexGenes, comparLst, diffSex, savePath)
#      61 ax4.set_title('UMAP Divided by Sample (Sex Genes Excluded)')
#      63 obj_sexGenes.uns['log1p'] = {'base': None}
# ---> 64 sc.tl.rank_genes_groups(obj_sexGenes, groupby='sample', method='wilcoxon')
#      65 deGraph(obj_sexGenes, sample1_name, sample2_name, 15, ax5)
#      66 deGraph(obj_sexGenes, sample2_name, sample1_name, 15, ax6)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\tools\_rank_genes_groups.py:608, in rank_genes_groups(adata, groupby, use_raw, groups, reference, n_genes, rankby_abs, pts, key_added, copy, method, corr_method, tie_correct, layer, **kwds)
#     605 logg.debug(f'consider {groupby!r} groups:')
#     606 logg.debug(f'with sizes: {np.count_nonzero(test_obj.groups_masks, axis=1)}')
# --> 608 test_obj.compute_statistics(
#     609     method, corr_method, n_genes_user, rankby_abs, tie_correct, **kwds
#     610 )
#     612 if test_obj.pts is not None:
#     613     groups_names = [str(name) for name in test_obj.groups_order]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\tools\_rank_genes_groups.py:378, in _RankGenes.compute_statistics(self, method, corr_method, n_genes_user, rankby_abs, tie_correct, **kwds)
#     374 self.stats = None
#     376 n_genes = self.X.shape[1]
# --> 378 for group_index, scores, pvals in generate_test_results:
#     379     group_name = str(self.groups_order[group_index])
#     381     if n_genes_user is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\tools\_rank_genes_groups.py:305, in _RankGenes.wilcoxon(self, tie_correct)
#     302 if tie_correct:
#     303     T = np.zeros((n_groups, n_genes))
# --> 305 for ranks, left, right in _ranks(self.X):
#     306     # sum up adjusted_ranks to calculate W_m,n
#     307     for imask, mask in enumerate(self.groups_masks):
#     308         scores[imask, left:right] = np.sum(ranks.iloc[mask, :])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\tools\_rank_genes_groups.py:63, in _ranks(X, mask, mask_rest)
#      60 right = min(left + max_chunk, n_genes)
#      62 df = pd.DataFrame(data=get_chunk(X, left, right))
# ---> 63 ranks = df.rank()
#      64 yield ranks, left, right
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:9174, in NDFrame.rank(self, axis, method, numeric_only, na_option, ascending, pct)
#    9172 if numeric_only is None:
#    9173     try:
# -> 9174         return ranker(self)
#    9175     except TypeError:
#    9176         numeric_only = True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:9158, in NDFrame.rank.<locals>.ranker(data)
#    9150     ranks = values._rank(
#    9151         axis=axis,
#    9152         method=method,
#    (...)
#    9155         pct=pct,
#    9156     )
#    9157 else:
# -> 9158     ranks = algos.rank(
#    9159         values,
#    9160         axis=axis,
#    9161         method=method,
#    9162         ascending=ascending,
#    9163         na_option=na_option,
#    9164         pct=pct,
#    9165     )
#    9167 ranks_obj = self._constructor(ranks, **data._construct_axes_dict())
#    9168 return ranks_obj.__finalize__(self, method="rank")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\algorithms.py:1144, in rank(values, axis, method, na_option, ascending, pct)
#    1135     ranks = algos.rank_1d(
#    1136         values,
#    1137         is_datetimelike=is_datetimelike,
#    (...)
#    1141         pct=pct,
#    1142     )
#    1143 elif values.ndim == 2:
# -> 1144     ranks = algos.rank_2d(
#    1145         values,
#    1146         axis=axis,
#    1147         is_datetimelike=is_datetimelike,
#    1148         ties_method=method,
#    1149         ascending=ascending,
#    1150         na_option=na_option,
#    1151         pct=pct,
#    1152     )
#    1153 else:
#    1154     raise TypeError("Array with ndim > 2 are not supported.")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\algos.pyx:1376, in pandas._libs.algos.rank_2d()
#
# File <__array_function__ internals>:180, in lexsort(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
savePath = 'F:/Figures/Figure8/BiologicalReplica' 
plottingFigure8(bioRepComparisonLst, 'BiologicalReplicaSamples', 'BiologicalReplicaSamples_noSexGenes', savePath)
