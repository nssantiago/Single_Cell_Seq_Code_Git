# %%
import anndata, pickle, os, fnmatch, math, random
import scipy.stats as stats
import statistics as st
import scanpy as sc
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib as mlp
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import colors
from matplotlib.colors import ListedColormap
from matplotlib.ticker import MultipleLocator, LogLocator, LogFormatter, LogFormatterSciNotation, MaxNLocator
import matplotlib.patches as mpatches

# %%
'''IMPORTING FUNCTIONS FROM GENERAL FUNCTIONS FILE'''

# %run GeneralFunctions.ipynb
# %run Figure8_Functions.ipynb

# %%
savePath = 'F:/Figures/Figure8/PlasticityComparisons' 
plottingFigure8(plastComparLst, 'PlasticityComparisons', 'PlasticityComparisons_noSexGenes', savePath)
# Out:
# C:\Users\Hlab\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\Hlab\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\Hlab\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\Hlab\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [6], line 2
#       1 savePath = 'F:/Figures/Figure8/PlasticityComparisons'
# ----> 2 plottingFigure8(plastComparLst, 'PlasticityComparisons', 'PlasticityComparisons_noSexGenes', savePath)
#
# File ~\AppData\Local\Temp\ipykernel_12168\2938400111.py:10, in plottingFigure8(sampleComparLst, sampleFolder_sexGenes, sampleFolder_noSexGenes, savePath)
#       7 obj_sexGenes = sc.read(f'F:/SampleData/{sampleFolder_sexGenes}/{condition}_{sample1_name}_{sample2_name}.h5ad')
#       8 obj_noSexGenes = sc.read(f'F:/SampleData/{sampleFolder_noSexGenes}/{condition}_{sample1_name}_{sample2_name}.h5ad')
# ---> 10 figure8(obj_sexGenes, obj_noSexGenes, lst, savePath)
#
# File ~\AppData\Local\Temp\ipykernel_12168\2959617496.py:96, in figure8(obj_sexGenes, obj_noSexGenes, comparLst, savePath)
#      94 # DE Graph NO GENES
#      95 obj_noSexGenes.uns['log1p'] = {'base': None}
# ---> 96 sc.tl.rank_genes_groups(obj_noSexGenes, groupby='sex', method='wilcoxon', use_raw=False)
#      97 deGraph(obj_noSexGenes, samle1_name, samle2_name, 10, ax9)
#      98 deGraph(obj_noSexGenes, samle2_name, samle1_name, 10, ax10)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\tools\_rank_genes_groups.py:608, in rank_genes_groups(adata, groupby, use_raw, groups, reference, n_genes, rankby_abs, pts, key_added, copy, method, corr_method, tie_correct, layer, **kwds)
#     605 logg.debug(f'consider {groupby!r} groups:')
#     606 logg.debug(f'with sizes: {np.count_nonzero(test_obj.groups_masks, axis=1)}')
# --> 608 test_obj.compute_statistics(
#     609     method, corr_method, n_genes_user, rankby_abs, tie_correct, **kwds
#     610 )
#     612 if test_obj.pts is not None:
#     613     groups_names = [str(name) for name in test_obj.groups_order]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\tools\_rank_genes_groups.py:378, in _RankGenes.compute_statistics(self, method, corr_method, n_genes_user, rankby_abs, tie_correct, **kwds)
#     374 self.stats = None
#     376 n_genes = self.X.shape[1]
# --> 378 for group_index, scores, pvals in generate_test_results:
#     379     group_name = str(self.groups_order[group_index])
#     381     if n_genes_user is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\tools\_rank_genes_groups.py:250, in _RankGenes.wilcoxon(self, tie_correct)
#     247 def wilcoxon(self, tie_correct):
#     248     from scipy import stats
# --> 250     self._basic_stats()
#     252     n_genes = self.X.shape[1]
#     253     # First loop: Loop over all genes
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\tools\_rank_genes_groups.py:190, in _RankGenes._basic_stats(self)
#     188 mask_rest = ~mask
#     189 X_rest = self.X[mask_rest]
# --> 190 self.means_rest[imask], self.vars_rest[imask] = _get_mean_var(X_rest)
#     191 # this can be costly for sparse data
#     192 if self.comp_pts:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\preprocessing\_utils.py:8, in _get_mean_var(X, axis)
#       6 def _get_mean_var(X, *, axis=0):
#       7     if sparse.issparse(X):
# ----> 8         mean, var = sparse_mean_variance_axis(X, axis=axis)
#       9     else:
#      10         mean = np.mean(X, axis=axis, dtype=np.float64)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\preprocessing\_utils.py:42, in sparse_mean_variance_axis(mtx, axis)
#      38     return sparse_mean_var_major_axis(
#      39         mtx.data, mtx.indices, mtx.indptr, *shape, np.float64
#      40     )
#      41 else:
# ---> 42     return sparse_mean_var_minor_axis(mtx.data, mtx.indices, *shape, np.float64)
#
# ZeroDivisionError: division by zero

# %%
savePath = 'F:/Figures/Figure8/BiologicalReplica' 
plottingFigure8(bioRepComparisonLst, 'BiologicalReplicaSamples', 'BiologicalReplicaSamples_noSexGenes', savePath)
