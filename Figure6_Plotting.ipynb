# %%
import anndata, pickle, os, fnmatch, math, random
import scipy.stats as stats
import statistics as st
import scanpy as sc
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib as mlp
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import colors
from matplotlib.colors import ListedColormap
from matplotlib.ticker import MultipleLocator, LogLocator, LogFormatter, LogFormatterSciNotation, MaxNLocator
import matplotlib.patches as mpatches

# %%
'''IMPORTING NECESSARY FUNCTIONS FROM GENERAL FUNCTION FILE'''

# %run GeneralFunctions.ipynb
# %run Figure6_Functions.ipynb

# %%
'''IMPORTING NECESSARY LIST FROM FIGURE6_CALCULATIONS FILE'''

# %run -i Figure6_Calculations.ipynb
# Out:
# VC Deaf vs. Control_5_VC22L_7_VC24L
# VC Deaf vs. Control_10_VC25L_9_VC23L
# AC Deaf vs. Control_6_AC22L_8_AC24L
# AC Deaf vs. Control_13_AC25L_14_AC23L
# Stored 'plastComparFvsM' (list)

# %%
'''CREATING FIGURE 6'''

savePath = 'F:/Figures/Figure6/'
makingFigure6(plastComparFvsM, savePath)
# Out:
# C:\Users\Hlab\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\Hlab\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\Hlab\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# C:\Users\Hlab\AppData\Local\Programs\Python\Python310\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
`
